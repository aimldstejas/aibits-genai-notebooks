# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aimldstejas/aibits-genai-notebooks/blob/main/ml/02-python-for-data-science/pyds-viz-plotly.ipynb)
#
# # Interactive Visualization with Plotly
#
# *AIBits Academy · Machine Learning End To End · Python For Data Science*
#
# **How to use this notebook:** run the cells top to bottom (Runtime → Run all). Each code cell is the same code you saw on the course page, so you can compare your output with the lesson. The graded exercises are at the end; try them before opening the solutions.
#
# *Interactive animations and quiz cards stay on the course page.*

# %% [markdown]
# Matplotlib and Seaborn produce *static* images. Plotly produces **interactive** charts — hover for exact values, zoom, pan, and rotate 3-D views right in the browser. Every chart on this page is live: try hovering and dragging.

# %% [markdown]
# > **💡 Install & import**
# >
# > Plotly installs with `pip install plotly`. The examples use **Plotly Express** (`plotly.express as px`) — its high-level API builds a full interactive figure in one line. The charts you see below are the same figures rendered live in your browser.

# %% [markdown]
# All examples use one small sales table:

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    'Month':   ['Jan','Feb','Mar','Apr','May','Jun'] * 2,
    'Product': ['A']*6 + ['B']*6,
    'Sales':   [240,300,280,360,420,390, 180,220,260,240,300,340],
})

# %% [markdown]
# ## Interactive Line Chart

# %% [markdown]
# Pass `color=` and Plotly draws one line per category with a legend. Hover any point to read its exact value; drag to zoom.

# %%
fig = px.line(df, x='Month', y='Sales', color='Product',
              markers=True, title='Monthly Sales by Product')
fig.show()

# %% [markdown]
# ## Interactive Bar Chart

# %% [markdown]
# Grouped bars compare products within each month. Hover for values; use the toolbar (top-right) to zoom, pan, or download a PNG.

# %%
fig = px.bar(df, x='Month', y='Sales', color='Product',
             barmode='group', title='Monthly Sales by Product')
fig.show()

# %% [markdown]
# ## Interactive Bubble Chart

# %% [markdown]
# A scatter where `size=` encodes a third variable and `hover_name=` sets the label. Here each city is a bubble sized by units sold.

# %%
cities = pd.DataFrame({
    'City':   ['Mumbai','Bengaluru','Hyderabad','Pune','Surat'],
    'Sales':  [820, 540, 430, 390, 300],
    'Profit': [210, 160, 120, 95, 70],
    'Units':  [50, 38, 30, 28, 22],
})
fig = px.scatter(cities, x='Sales', y='Profit', size='Units', color='City',
                 hover_name='City', size_max=40, title='Sales vs Profit by City')
fig.show()

# %% [markdown]
# ## Interactive 3-D Scatter

# %% [markdown]
# Plotly's signature trick: a true 3-D plot you can **rotate** by dragging. Impossible with static Matplotlib. Click and drag the chart below to spin it.

# %%
fig = px.scatter_3d(cities, x='Sales', y='Profit', z='Units',
                    color='City', title='Sales / Profit / Units in 3-D')
fig.show()

# %% [markdown]
# > **⚠ Dashboards with Dash — beyond this course**
# >
# > Plotly's companion library **Dash** turns these charts into full interactive web-app dashboards with dropdowns and sliders. Because Dash runs its own web server, it needs a Python backend and can't live inside a single static HTML page — so we note it here but don't build one. It's a natural next step once you deploy models.

# %% [markdown]
# > **✅ What You Can Now Do**
# >
# > You can build interactive line, bar, bubble, and 3-D charts with Plotly Express — the go-to when your audience needs to explore the data themselves rather than read a fixed image. Next: applying all three libraries in a full univariate EDA.

# %% [markdown]
# ---
# ## Graded exercises
#
# Each exercise has a **starter cell** you complete and a **check cell** that prints ✅ or ❌. The solution is folded away underneath — try first.

# %%
# --- self-check helper (used by the exercises) ---------------------------------------------
def check(name, ok):
    print(("\u2705 " if ok else "\u274c ") + name)

# %% [markdown]
# ### Exercise 1 · Easy · An interactive line chart
#
# Using Plotly Express, build `fig` — a line chart of `Visits` over `Week` from `traffic`, with the title `Weekly visits`.

# %%
import pandas as pd, plotly.express as px
traffic = pd.DataFrame({"Week": [1, 2, 3, 4, 5], "Visits": [120, 150, 170, 160, 210]})
fig = None   # TODO

# %%
try:
    check("one trace", fig is not None and len(fig.data) == 1)
    check("y values", list(fig.data[0].y) == [120, 150, 170, 160, 210])
    check("title", fig.layout.title.text == "Weekly visits")
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# import pandas as pd, plotly.express as px
# traffic = pd.DataFrame({"Week": [1, 2, 3, 4, 5], "Visits": [120, 150, 170, 160, 210]})
# fig = px.line(traffic, x="Week", y="Visits", title="Weekly visits")
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 · Medium · Colour by group
#
# Build `fig`: a grouped bar chart of `Sales` by `Region` (x), coloured by `Channel`, with `barmode="group"`.

# %%
import pandas as pd, plotly.express as px
sales = pd.DataFrame({"Region": ["N", "S", "N", "S"], "Channel": ["web", "web", "store", "store"], "Sales": [50, 70, 65, 40]})
fig = None   # TODO

# %%
try:
    check("one trace per channel", fig is not None and len(fig.data) == 2)
    check("grouped", fig.layout.barmode == "group")
    check("trace names", {t.name for t in fig.data} == {"web", "store"})
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# import pandas as pd, plotly.express as px
# sales = pd.DataFrame({"Region": ["N", "S", "N", "S"], "Channel": ["web", "web", "store", "store"], "Sales": [50, 70, 65, 40]})
# fig = px.bar(sales, x="Region", y="Sales", color="Channel", barmode="group")
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 · Stretch · Bubble chart with hover text
#
# Build `fig`: a scatter of `Spend` (x) vs `Revenue` (y) where marker **size** is `Customers`, the hover title is the `Campaign` name, and the x-axis is labelled `Ad spend (Rs)`.

# %%
import pandas as pd, plotly.express as px
camp = pd.DataFrame({"Campaign": ["Diwali", "Summer", "Launch"], "Spend": [50, 30, 80], "Revenue": [200, 90, 260], "Customers": [400, 150, 520]})
fig = None   # TODO

# %%
try:
    check("figure built", fig is not None and len(fig.data) >= 1)
    check("size mapped to Customers", list(fig.data[0].marker.size) == [400, 150, 520])
    check("x axis title", fig.layout.xaxis.title.text == "Ad spend (Rs)")
    check("hover names", list(fig.data[0].hovertext) == ["Diwali", "Summer", "Launch"])
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# import pandas as pd, plotly.express as px
# camp = pd.DataFrame({"Campaign": ["Diwali", "Summer", "Launch"], "Spend": [50, 30, 80], "Revenue": [200, 90, 260], "Customers": [400, 150, 520]})
# fig = px.scatter(camp, x="Spend", y="Revenue", size="Customers", hover_name="Campaign")
# fig.update_xaxes(title_text="Ad spend (Rs)")
#
# ```
#
# </details>

# %% [markdown]
# ---
# *Back to the course: **Machine Learning End To End → Interactive Visualization with Plotly**.*
