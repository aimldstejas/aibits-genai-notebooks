# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aimldstejas/aibits-genai-notebooks/blob/main/ml/02-python-for-data-science/pyds-pandas-intro.ipynb)
#
# # Pandas: Series & DataFrame
#
# *AIBits Academy · Machine Learning End To End · Python For Data Science*
#
# **How to use this notebook:** run the cells top to bottom (Runtime → Run all). Each code cell is the same code you saw on the course page, so you can compare your output with the lesson. The graded exercises are at the end; try them before opening the solutions.
#
# *Interactive animations and quiz cards stay on the course page.*

# %% [markdown]
# Pandas adds *labels* to NumPy's arrays. The one-dimensional `Series` and the two-dimensional `DataFrame` are the structures you'll load, clean, filter, and analyse for the rest of this course.

# %% [markdown]
# A **Series** is a labelled 1-D array; a **DataFrame** is a labelled 2-D table — essentially a dictionary of Series sharing one index. Every column is a Series.

# %% [markdown]
# ## Series

# %% [markdown]
# Create a Series from a list. Without an index, pandas assigns integer positions 0, 1, 2, … — just like a list, but you can attach your own labels instead.

# %%
import pandas as pd

data = [10, 20, 30, 40, 50]
series = pd.Series(data)
print(series)
print("dtype:", series.dtype)

# %% [markdown]
# Supplying an `index` gives each value a meaningful label you can look up by.

# %%
import pandas as pd

data = [10, 20, 30, 40, 50, 60]
index = ['a', 'b', 'c', 'x', 'y', 'z']
series = pd.Series(data, index=index)
print(series)
print("series['c']:", series['c'])

# %% [markdown]
# ## DataFrame

# %% [markdown]
# The most common way to build a DataFrame is from a dictionary — each key becomes a column, each list becomes that column's values.

# %%
import pandas as pd

data = {
    'City': ['Mumbai', 'Surat', 'Bengaluru'],
    'Total_Population': [340, 120, 280],
    'Literacy_Rate': [89.2, 85.4, 88.7],
}
df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ### Accessing Columns & Rows

# %% [markdown]
# Index a column by its label (returns a Series). Use `.iloc` for integer-position row access, and `.loc` with a boolean condition to select rows by value.

# %%
import pandas as pd

data = {
    'City': ['Mumbai', 'Surat', 'Bengaluru'],
    'Total_Population': [340, 120, 280],
    'Literacy_Rate': [89.2, 85.4, 88.7],
}
df = pd.DataFrame(data)

print("column City:\n", df['City'])
print("first row (iloc[0]):\n", df.iloc[0])
print("rows where population == 340:\n", df.loc[df['Total_Population'] == 340])

# %% [markdown]
# ### From a List of Records & Boolean Filtering

# %% [markdown]
# A list of dictionaries builds a DataFrame row by row. A comparison like `df['Age'] > 25` creates a boolean Series that filters the rows.

# %%
import pandas as pd

data = [
    {'Name': 'Anaya', 'Age': 28, 'City': 'Mumbai'},
    {'Name': 'Rohan', 'Age': 34, 'City': 'Surat'},
    {'Name': 'Isha',  'Age': 22, 'City': 'Pune'},
]
df = pd.DataFrame(data)
print(df)
print("rows where Age > 25:\n", df.loc[df['Age'] > 25])

# %% [markdown]
# ## Loading Data from Files

# %% [markdown]
# > **💡 The read_* family**
# >
# > Real projects load data from files rather than typing it in. Pandas has a reader for every common format — the calls below show the syntax; each returns a DataFrame you then explore with the methods in the next section.

# %% [markdown]
# The next cell reads files, so first we create small sample files to read.

# %%
import pandas as pd
sample = pd.DataFrame({"Name": ["Anaya", "Rohan", "Isha"], "Age": [28, 34, 22], "City": ["Mumbai", "Surat", "Pune"]})
sample.to_csv("data.csv", index=False)
sample.to_csv("data.tsv", index=False, sep="\t")
sample.to_excel("data.xlsx", index=False)      # needs openpyxl (pre-installed in Colab)
print("created data.csv, data.tsv, data.xlsx")

# %%
import pandas as pd

df_csv = pd.read_csv('data.csv')                 # comma-separated
df_tsv = pd.read_csv('data.tsv', delimiter='\t')  # tab-separated
df_xls = pd.read_excel('data.xlsx')              # Excel workbook
# df_url = pd.read_csv('https://example.com/data.csv')  # straight from a URL (use a real address)

print(df_csv.head())   # peek at the first 5 rows

# %% [markdown]
# ## Exploring a DataFrame

# %% [markdown]
# Once data is loaded, a handful of methods give you a fast overview. We'll use a synthetic 30-row employee table (fixed seed, so the numbers are reproducible) with three numeric and two categorical columns.

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
n = 30
df = pd.DataFrame({
    'Age': np.random.randint(22, 60, n),
    'Income': np.random.randint(30000, 120000, n),
    'Years_Employed': np.random.randint(1, 25, n),
    'Department': np.random.choice(['Engineering', 'Marketing', 'Finance'], n, p=[0.5, 0.3, 0.2]),
    'Location': np.random.choice(['Mumbai', 'Bengaluru', 'Hyderabad'], n, p=[0.5, 0.3, 0.2]),
})
print(df.head())          # first 5 rows
print("shape:", df.shape) # (rows, columns)

# %% [markdown]
# `dtypes` reports each column's type, and `describe()` summarises the numeric columns in one shot.

# %%
print(df.dtypes)
print(df.describe().round(1))

# %% [markdown]
# For categorical columns, `value_counts()` tallies each category and `unique()` lists the distinct values.

# %%
print(df['Department'].value_counts())
print("locations:", df['Location'].unique())

# %% [markdown]
# > **✅ What You Can Now Do**
# >
# > You can build Series and DataFrames, access columns and rows with labels, `.iloc`, and `.loc`, filter with boolean conditions, load data from files, and profile a table with `head`, `describe`, and `value_counts`. Next: reshaping and wrangling messier data with pandas.

# %% [markdown]
# ---
# ## Graded exercises
#
# Each exercise has a **starter cell** you complete and a **check cell** that prints ✅ or ❌. The solution is folded away underneath — try first.

# %%
# --- self-check helper (used by the exercises) ---------------------------------------------
def check(name, ok):
    print(("\u2705 " if ok else "\u274c ") + name)

# %% [markdown]
# ### Exercise 1 · Easy · Build a DataFrame and filter it
#
# Store in `seniors` the rows of `staff` where `Years` is at least 5.

# %%
import pandas as pd
staff = pd.DataFrame({"Name": ["Ana", "Sam", "Priya", "Leo"], "Dept": ["ML", "Product", "Data", "Finance"], "Years": [7, 3, 5, 2]})
seniors = None   # TODO

# %%
try:
    check("two seniors", seniors is not None and len(seniors) == 2)
    check("names", seniors["Name"].tolist() == ["Ana", "Priya"])
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# import pandas as pd
# staff = pd.DataFrame({"Name": ["Ana", "Sam", "Priya", "Leo"], "Dept": ["ML", "Product", "Data", "Finance"], "Years": [7, 3, 5, 2]})
# seniors = staff[staff["Years"] >= 5]
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 · Medium · Summarise by group
#
# Using `orders`, compute `by_channel`: the **mean** `Amount` for each `Channel`, as a Series indexed by channel.

# %%
import pandas as pd
orders = pd.DataFrame({"Channel": ["web", "store", "web", "app", "store", "app"], "Amount": [200, 150, 300, 120, 250, 180]})
by_channel = None   # TODO

# %%
try:
    check("three channels", by_channel is not None and len(by_channel) == 3)
    check("web average", by_channel["web"] == 250)
    check("app average", by_channel["app"] == 150)
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# import pandas as pd
# orders = pd.DataFrame({"Channel": ["web", "store", "web", "app", "store", "app"], "Amount": [200, 150, 300, 120, 250, 180]})
# by_channel = orders.groupby("Channel")["Amount"].mean()
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 · Stretch · Round-trip through a CSV
#
# Save `orders` to `orders.csv` without the index, read it back with `pd.read_csv` into `again`, and set `same` to `True` if `again` equals `orders` (use `DataFrame.equals`).

# %%
again = None
same = None
# TODO

# %%
try:
    check("read back correctly", same is True)
except Exception as e:
    print("\u274c Not ready yet (" + type(e).__name__ + ") - complete the starter cell above, then run this again.")

# %% [markdown]
# <details><summary><b>Show solution</b></summary>
#
# ```python
# orders.to_csv("orders.csv", index=False)
# again = pd.read_csv("orders.csv")
# same = bool(again.equals(orders))
#
# ```
#
# </details>

# %% [markdown]
# ---
# *Back to the course: **Machine Learning End To End → Pandas: Series & DataFrame**.*
