# %% [markdown]
# <a href="https://colab.research.google.com/github/aimldstejas/aibits-genai-notebooks/blob/main/course-3-ai-agents/lab-11-capstone-starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone starter — a scoped, evaluated, deployed agent
# **Course 3: AI Agents and Agentic AI with Python — Chapter 11: Capstone**
#
# This is a **scaffold**, not a solved lab. Pick any cast scenario from Chapters 1–9 (or
# propose your own with real tools, real data, and a rubric check). **A well-argued "this
# should be a workflow, not an agent" capstone is acceptable** and is graded on the same rigor
# as a full agent build.

# %% [markdown]
# ## 1. Scoping note
# - **Cast scenario / org:** _fill in_
# - **Agent vs. workflow decision, and why:** _fill in — argue it, don't assume it_
# - **The action space (what tools/capabilities does it need):** _fill in_
# - **Guardrails (max steps, timeout, budget, actions requiring human approval):** _fill in_
# - **Target success rate + cost budget per task:** _fill in_

# %% [markdown]
# ## 2. The agent (or justified workflow)

# %%
import os
try:
    from google.colab import userdata
    API_KEY = userdata.get('LLM_API_KEY'); BASE_URL = userdata.get('LLM_BASE_URL')
except Exception:
    API_KEY = os.environ.get('LLM_API_KEY'); BASE_URL = os.environ.get('LLM_BASE_URL')
hosted_available = bool(API_KEY and BASE_URL)
print('Hosted API available:', hosted_available)

# %%
TOOLS = {
    # TODO: real tools for your scenario, each with validation (Lab 2's pattern) and a
    # documented safe/unsafe classification (Lab 9's pattern)
}

def think_mock(history, goal):
    """TODO: a scripted offline policy (Lab 1's pattern) so this works with zero cost/key."""
    raise NotImplementedError

def run_agent(goal, max_steps=6, timeout_s=30, max_cost_units=10, think_fn=None):
    """TODO: reuse Lab 1's guardrailed loop shape — max steps, timeout, budget, explicit
    failure state, never a silent guess."""
    raise NotImplementedError

# %% [markdown]
# ## 3. Evaluation suite
# Outcome + trajectory metrics (Lab 8's `AgentTask`/`run_suite` pattern), an LLM-judge
# calibrated against a small human-labeled set, cost/latency results, and at least one
# regression test.

# %%
# TODO: task_suite = [AgentTask(...), ...]
# TODO: results, outcome_rate, trajectory_rate = run_suite(task_suite)
# TODO: a calibrated LLM-judge, and at least one wired regression test (Lab 8/10's pattern)

# %% [markdown]
# ## 4. Security review
# Threat model, the actions requiring human approval, applied defenses (Lab 9's pattern), and a
# red-team result.

# %%
# TODO: at least one real attack attempt (indirect injection, permission escalation) against
# your unprotected agent, then the defenses, then a re-run showing the measured reduction.

# %% [markdown]
# ## 5. Deployed, gated, monitored
# Tracing + cost logging + budget caps, the eval suite as a release gate, and at least one
# drift monitor (tool contract test or canary suite — Lab 10's pattern).

# %%
# TODO: a Traced*Agent class (Lab 10's pattern), a release_gate function, and a
# contract_test or canary_suite drift monitor

# %% [markdown]
# ## 6. Decision dossier (3–4 pages, fill in)
# - **Capability:** _fill in_
# - **Cost at target volume:** _fill in_
# - **Failure modes:** _fill in_
# - **Safety posture:** _fill in_
# - **Monitoring plan:** _fill in_
# - **Verdict — ship / don't ship / ship with conditions:** _fill in, with justification_
#
# ---
# *Beacon AI · AIBits Academy — Chapter 11: Capstone*
